# %%
print("Hello, AI world")

# %% [markdown]
# Asalam O Alaikum, I am Taha, I'm currently enrolled in the 7th Semester in bachelors of Computer Science at Institute of Business Management Karachi, I'm currently working as an AI-ML Intern at coretchio.
